# %% [markdown]
# In this notebook I'll wrangle the data for my capstone 2 project.

# %%
#imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import numpy as np
import re
#from library.sb_utils import save_file

# %% [markdown]
# Next I'll upload my data. My primary source is the district snapshot. This dataset is highly descriptive but lacks readability so I'll likely have to take a look at if all the information contained is relevant. I'll also upload a more descriptive dataset of teacher salaries and private school information. I'll go through the data to make sure there are no issues and then join it into one dataframe.

# %%
wdir = os.getcwd()
print(wdir)
# Out:
# C:\Users\Armstrongs\Desktop\GitHub\Capstone2

# %%
directories = os.listdir()
print(directories)
# Out:
# ['.git', '.ipynb_checkpoints', 'Capstone 2 Data Wrangling.ipynb', 'district_summary.csv', 'privateSchoolData - allSchoolData.csv', 'Staff Salary FTE Report_Statewide_Districts_2019-2020 - Staff Salary FTE Report_Statewide_Districts_2019-2020.csv']

# %%
snapshot2019 = pd.read_csv('district_summary.csv')

# %%
print(type(snapshot2019))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
snapshot2019.head()
# Out:
#         DISTNAME  DISTRICT      DZCNTYNM  REGION DZRATING  DZCAMPUS  DPETALLC  \
# 0     CAYUGA ISD      1902  001 ANDERSON       7        A         3       564
# 1    ELKHART ISD      1903  001 ANDERSON       7        A         5      1254
# 2  FRANKSTON ISD      1904  001 ANDERSON       7        B         3       803
# 3     NECHES ISD      1906  001 ANDERSON       7        A         2       366
# 4  PALESTINE ISD      1907  001 ANDERSON       7        B         6      3389
#
#    DPETBLAP  DPETHISP  DPETWHIP  ...  DPFPAVOCP  DPFPAGIFP  DPFPAATHP  \
# 0       3.5       6.7      84.8  ...        2.8        0.1        3.6
# 1       5.4      11.3      78.1  ...        7.8        0.1        3.4
# 2       8.2       8.2      78.2  ...        6.9        0.1        7.3
# 3       8.5      13.9      73.2  ...          4        0.3          0
# 4      26.6      41.2      27.5  ...        3.9        0.2        3.4
#
#    DPFPAHSAP  DPFPREKP  DPFPAOTHP        DISTSIZE                 COMMTYPE  \
# 0        0.6       0.3       20.8      500 to 999                    Rural
# 1          1         0       25.7  1,000 to 1,599  Non-metropolitan Stable
# 2          1       1.1       28.2      500 to 999                    Rural
# 3        1.2       0.5       35.1       Under 500                    Rural
# 4        0.7       2.1       28.3  3,000 to 4,999         Independent Town
#
#                  PROPWLTH                   TAXRATE
# 0  $442,675 to < $456,961             Under $1.1701
# 1  $164,221 to < $208,918  $1.3050 to under $1.4272
# 2  $272,534 to < $299,260          $1.4272 and over
# 3  $272,534 to < $299,260          $1.4272 and over
# 4  $299,260 to < $316,695          $1.4272 and over
#
# [5 rows x 137 columns]

# %%
#changing the column "district" to solve a conflict futher down
snapshot2019.rename({'DISTRICT' : 'D'}, axis=1, inplace=True)

# %%
snapshotcolnames = ['DISTNAME',
'DISTRICT #',
'DZCNTYNM',
'REGION',
'DZRATING',
'DZCAMPUS',
'total students',
'4. Students % African American: ',
'5. Students % Hispanic: ',
'6. Students % White:' ,
'7. Students % American Indian:' ,
'8. Students % Asian:',
'9. Students % Pacific Islander:' ,
'10. Students % Two or More Races:',
'11. Students % Economically Disadvantaged:',
'12. Students % English Learners (EL):' ,
'13. Students % Special Education:' ,
'14. Students % Bilingual/ESL Education:' ,
'15. Students % Career and Technical Education:',
'16. Students % Gifted and Talented Education:' ,
'17. Attendance Rate (2017-18):' ,
'18. Annual Dropout Rate Gr. 9-12 (2017-18):' ,
'19. 4-Year Longitudinal Graduation Rate (Class of 2018):',
'20. 5-Year Longitudinal Graduation Rate (Class of 2017):',
'21. 6-Year Longitudinal Graduation Rate (Class of 2016):',
'22. Annual Graduate Count (2017-18):',
'23. Annual RHSP/DAP/FHSP-E/FHSP-DLA Graduate Count (2017-18):',
'staar all subjects approach',
'staar all subjects meet',
'staar all subjects master',
'staar elar approach',
'staar elar meets',
'staar elar master',
'staar write approach',
'staar write meet',
'staar write master',
'staar math approach',
'staar math meet',
'staar math master',
'staar science approach',
'staar science meet',
'staar science master',
'staar social approach',
'staar social meet',
'staar social master',
'staar african approach',
'staar african meet',
'staar african master',
'staar hispanic approach',
'staar hispanic meet',
'staar hispanic master',
'staar white approach',
'staar white meet',
'staar white master',
'staar native approach',
'staar native meet',
'staar native master',
'staar asian approach',
'staar asian meet',
'staar asian master',
'staar pacific approach',
'staar pacific meet',
'staar pacific master',
'2+ race approach',
'2+ race meet',
'2+ race master',
'econ disad approach',
'econ disad meet',
'econ disad master',
'38. SAT/ACT Results - % Tested (2017-2018):' ,
'39. SAT/ACT Results - % At or Above Criterion (2017-2018): ',
'40. SAT - Average Score (2017-2018):' ,
'41. ACT - Average Score (2017-2018):',
'42. Total Staff FTE:' ,
'43. Total Teacher FTE: ',
'44. Staff % Central Administration:' ,
'45. Staff % Campus Administration:' ,
'46. Staff % Professional Support:' ,
'47. Staff % Teachers:',
'48. Staff % Educational Aides:' ,
'49. Staff % Auxiliary:' ,
'50. Average Central Administrative Salary:' ,
'51. Average Campus Administrative Salary:',
'52. Average Professional Support Staff Salary:',
'53. Average Teacher Salary:' ,
'54. Staff % Minority:' ,
'55. Number of Students Per Total Staff: ',
'56. Number of Students Per Teacher:' ,
'57. Teacher % With 5 or Fewer Years of Experience: ',
'58. Teacher Average Years of Experience:' ,
'59. Teacher % With Advanced Degrees:',
'60. Teacher Turnover Rate:' ,
'61. Teacher % African American:',
'62. Teacher % Hispanic:' ,
'63. Teacher % White:' ,
'64. Teacher % Other:' ,
'65. Teacher % Regular Education:' ,
'66. Teacher % Special Education:',
'67. Teacher % Compensatory Education:' ,
'68. Teacher % Bilingual/ESL Education:' ,
'69. Teacher % Career and Technical Education:' ,
'70. Teacher % Other Education (Includes Gifted and Talented):' ,
'71. Taxable Value Per Pupil (2016 Tax Year):' ,
'72. Locally Adopted Tax Rate (2017 Tax Year):' ,
'73. Total Operating and Other Revenue (2017-18):',
'74. Total Operating and Other Revenue Per Pupil:' ,
'75. Total Operating Revenue (2017-18):' ,
'76. Operating Revenue % State:' ,
'77. Operating Revenue % Local and Other:',
'78. Operating Revenue % Federal:' ,
'79. Total Other Revenue (2017-18):' ,
'80. Fund Balance (For ISDs):' ,
'81. Net Assets (Charter Schools):' ,
'82. Total Actual Expenditures (2017-18): ',
'83. Total Actual Operating Expenditures (2017-18):' ,
'84. Total Actual Operating Expenditures Per Pupil:',
'85. Expenditure % Instructional:' ,
'86. Expenditure % Central Administrative: ',
'87. Expenditure % School Leadership:' ,
'88. Expenditure % Plant Services: ',
'89. Expenditure % Other Operating:' ,
'90. Total Actual Instructional Expenditures (2017-2018):' ,
'91. Total Actual Instructional Expenditures Per Pupil:',
'92. Expenditures % Basic Education Services: ',
'93. Expenditures % Special Education:',
'94. Expenditures % State Compensatory Education:',
'95. Expenditures % Bilingual/ESL Education:',
'96. Expenditures % Career and Technical Education:' ,
'97. Expenditures % Gifted and Talented Education:',
'98. Expenditures % Athletics/Related Activities:' ,
'99. Expenditures % High School Allotment:',
'100. Expenditures % Prekindergarten:',
'101. Expenditures % Un-Allocated:',
'DISTSIZE',
'COMMTYPE',
'PROPWLTH',
'TAXRATE',
                   ]
#These were generated by using this dictionary
#https://rptsvr1.tea.texas.gov/perfreport/snapshot/2019/itemdef.html
#and comparing the dataset against a report for a specific district
#Example: https://rptsvr1.tea.texas.gov/perfreport/snapshot/2019/district.srch.html search CAYUGA ISD
#and compare values to dataset.

# %%
codedcolnames = [code for code in snapshot2019.columns]

# %%
codedcolnames[:5]
# Out:
# ['DISTNAME', 'D', 'DZCNTYNM', 'REGION', 'DZRATING']

# %%
#I want to make sure that the new column names match the values for the dataframe exactly. They should be the same length. 
print(len(snapshotcolnames))
print(len(codedcolnames))
# Out:
# 137
# 137

# %%
valuesdict = {}
for key in snapshotcolnames:
    for value in codedcolnames:
        valuesdict[key] = value
        codedcolnames.remove(value)
        break

# %%
valuesdict
# Out:
# {'DISTNAME': 'DISTNAME',
#  'DISTRICT #': 'D',
#  'DZCNTYNM': 'DZCNTYNM',
#  'REGION': 'REGION',
#  'DZRATING': 'DZRATING',
#  'DZCAMPUS': 'DZCAMPUS',
#  'total students': 'DPETALLC',
#  '4. Students % African American: ': 'DPETBLAP',
#  '5. Students % Hispanic: ': 'DPETHISP',
#  '6. Students % White:': 'DPETWHIP',
#  '7. Students % American Indian:': 'DPETINDP',
#  '8. Students % Asian:': 'DPETASIP',
#  '9. Students % Pacific Islander:': 'DPETPCIP',
#  '10. Students % Two or More Races:': 'DPETTWOP',
#  '11. Students % Economically Disadvantaged:': 'DPETECOP',
#  '12. Students % English Learners (EL):': 'DPETLEPP',
#  '13. Students % Special Education:': 'DPETSPEP',
#  '14. Students % Bilingual/ESL Education:': 'DPETBILP',
#  '15. Students % Career and Technical Education:': 'DPETVOCP',
#  '16. Students % Gifted and Talented Education:': 'DPETGIFP',
#  '17. Attendance Rate (2017-18):': 'DA0AT18R',
#  '18. Annual Dropout Rate Gr. 9-12 (2017-18):': 'DA0912DR18R',
#  '19. 4-Year Longitudinal Graduation Rate (Class of 2018):': 'DAGC4X18R',
#  '20. 5-Year Longitudinal Graduation Rate (Class of 2017):': 'DAGC5X17R',
#  '21. 6-Year Longitudinal Graduation Rate (Class of 2016):': 'DAGC6X16R',
#  '22. Annual Graduate Count (2017-18):': 'DA0GR18N',
#  '23. Annual RHSP/DAP/FHSP-E/FHSP-DLA Graduate Count (2017-18):': 'DA0GS18N',
#  'staar all subjects approach': 'DDA00A001S19R',
#  'staar all subjects meet': 'DDA00A001219R',
#  'staar all subjects master': 'DDA00A001319R',
#  'staar elar approach': 'DDA00AR01S19R',
#  'staar elar meets': 'DDA00AR01219R',
#  'staar elar master': 'DDA00AR01319R',
#  'staar write approach': 'DDA00AW01S19R',
#  'staar write meet': 'DDA00AW01219R',
#  'staar write master': 'DDA00AW01319R',
#  'staar math approach': 'DDA00AM01S19R',
#  'staar math meet': 'DDA00AM01219R',
#  'staar math master': 'DDA00AM01319R',
#  'staar science approach': 'DDA00AC01S19R',
#  'staar science meet': 'DDA00AC01219R',
#  'staar science master': 'DDA00AC01319R',
#  'staar social approach': 'DDA00AS01S19R',
#  'staar social meet': 'DDA00AS01219R',
#  'staar social master': 'DDA00AS01319R',
#  'staar african approach': 'DDB00A001S19R',
#  'staar african meet': 'DDB00A001219R',
#  'staar african master': 'DDB00A001319R',
#  'staar hispanic approach': 'DDH00A001S19R',
#  'staar hispanic meet': 'DDH00A001219R',
#  'staar hispanic master': 'DDH00A001319R',
#  'staar white approach': 'DDW00A001S19R',
#  'staar white meet': 'DDW00A001219R',
#  'staar white master': 'DDW00A001319R',
#  'staar native approach': 'DDI00A001S19R',
#  'staar native meet': 'DDI00A001219R',
#  'staar native master': 'DDI00A001319R',
#  'staar asian approach': 'DD300A001S19R',
#  'staar asian meet': 'DD300A001219R',
#  'staar asian master': 'DD300A001319R',
#  'staar pacific approach': 'DD400A001S19R',
#  'staar pacific meet': 'DD400A001219R',
#  'staar pacific master': 'DD400A001319R',
#  '2+ race approach': 'DD200A001S19R',
#  '2+ race meet': 'DD200A001219R',
#  '2+ race master': 'DD200A001319R',
#  'econ disad approach': 'DDE00A001S19R',
#  'econ disad meet': 'DDE00A001219R',
#  'econ disad master': 'DDE00A001319R',
#  '38. SAT/ACT Results - % Tested (2017-2018):': 'DA0CT18R',
#  '39. SAT/ACT Results - % At or Above Criterion (2017-2018): ': 'DA0CC18R',
#  '40. SAT - Average Score (2017-2018):': 'DA0CSA18R',
#  '41. ACT - Average Score (2017-2018):': 'DA0CAA18R',
#  '42. Total Staff FTE:': 'DPSATOFC',
#  '43. Total Teacher FTE: ': 'DPSTTOFC',
#  '44. Staff % Central Administration:': 'DPSCTOFP',
#  '45. Staff % Campus Administration:': 'DPSSTOFP',
#  '46. Staff % Professional Support:': 'DPSUTOFP',
#  '47. Staff % Teachers:': 'DPSTTOFP',
#  '48. Staff % Educational Aides:': 'DPSETOFP',
#  '49. Staff % Auxiliary:': 'DPSXTOFP',
#  '50. Average Central Administrative Salary:': 'DPSCTOSA',
#  '51. Average Campus Administrative Salary:': 'DPSSTOSA',
#  '52. Average Professional Support Staff Salary:': 'DPSUTOSA',
#  '53. Average Teacher Salary:': 'DPSTTOSA',
#  '54. Staff % Minority:': 'DPSAMIFP',
#  '55. Number of Students Per Total Staff: ': 'DPSAKIDR',
#  '56. Number of Students Per Teacher:': 'DPSTKIDR',
#  '57. Teacher % With 5 or Fewer Years of Experience: ': 'DPST05FP',
#  '58. Teacher Average Years of Experience:': 'DPSTEXPA',
#  '59. Teacher % With Advanced Degrees:': 'DPSTADFP',
#  '60. Teacher Turnover Rate:': 'DPSTURNR',
#  '61. Teacher % African American:': 'DPSTBLFP',
#  '62. Teacher % Hispanic:': 'DPSTHIFP',
#  '63. Teacher % White:': 'DPSTWHFP',
#  '64. Teacher % Other:': 'DPSTO2FP',
#  '65. Teacher % Regular Education:': 'DPSTREFP',
#  '66. Teacher % Special Education:': 'DPSTSPFP',
#  '67. Teacher % Compensatory Education:': 'DPSTCOFP',
#  '68. Teacher % Bilingual/ESL Education:': 'DPSTBIFP',
#  '69. Teacher % Career and Technical Education:': 'DPSTVOFP',
#  '70. Teacher % Other Education (Includes Gifted and Talented):': 'DPSTGOFP',
#  '71. Taxable Value Per Pupil (2016 Tax Year):': 'DPFVTOTK',
#  '72. Locally Adopted Tax Rate (2017 Tax Year):': 'DPFTADPR',
#  '73. Total Operating and Other Revenue (2017-18):': 'DPFRAALLT',
#  '74. Total Operating and Other Revenue Per Pupil:': 'DPFRAALLK',
#  '75. Total Operating Revenue (2017-18):': 'DPFRAOPRT',
#  '76. Operating Revenue % State:': 'DPFRASTAP',
#  '77. Operating Revenue % Local and Other:': 'DZRVLOCP',
#  '78. Operating Revenue % Federal:': 'DPFRAFEDP',
#  '79. Total Other Revenue (2017-18):': 'DPFRAORVT',
#  '80. Fund Balance (For ISDs):': 'DPFUNAB1T',
#  '81. Net Assets (Charter Schools):': 'DPFUNA4T',
#  '82. Total Actual Expenditures (2017-18): ': 'DPFEAALLT',
#  '83. Total Actual Operating Expenditures (2017-18):': 'DPFEAOPFT',
#  '84. Total Actual Operating Expenditures Per Pupil:': 'DPFEAOPFK',
#  '85. Expenditure % Instructional:': 'DPFEAINSP',
#  '86. Expenditure % Central Administrative: ': 'DZEXADMP',
#  '87. Expenditure % School Leadership:': 'DZEXADSP',
#  '88. Expenditure % Plant Services: ': 'DZEXPLAP',
#  '89. Expenditure % Other Operating:': 'DZEXOTHP',
#  '90. Total Actual Instructional Expenditures (2017-2018):': 'DPFEAINST',
#  '91. Total Actual Instructional Expenditures Per Pupil:': 'DPFEAINSK',
#  '92. Expenditures % Basic Education Services: ': 'DPFPAREGP',
#  '93. Expenditures % Special Education:': 'DPFPASPEP',
#  '94. Expenditures % State Compensatory Education:': 'DPFPACOMP',
#  '95. Expenditures % Bilingual/ESL Education:': 'DPFPABILP',
#  '96. Expenditures % Career and Technical Education:': 'DPFPAVOCP',
#  '97. Expenditures % Gifted and Talented Education:': 'DPFPAGIFP',
#  '98. Expenditures % Athletics/Related Activities:': 'DPFPAATHP',
#  '99. Expenditures % High School Allotment:': 'DPFPAHSAP',
#  '100. Expenditures % Prekindergarten:': 'DPFPREKP',
#  '101. Expenditures % Un-Allocated:': 'DPFPAOTHP',
#  'DISTSIZE': 'DISTSIZE',
#  'COMMTYPE': 'COMMTYPE',
#  'PROPWLTH': 'PROPWLTH',
#  'TAXRATE': 'TAXRATE'}

# %%
#Examine district of interest
cleburne = snapshot2019[snapshot2019['DISTNAME'] == 'CLEBURNE ISD'].T
cleburne
# Out:
#                                    669
# DISTNAME                  CLEBURNE ISD
# D                               126903
# DZCNTYNM                   126 JOHNSON
# REGION                              11
# DZRATING                             C
# ...                                ...
# DPFPAOTHP                         25.9
# DISTSIZE                5,000 to 9,999
# COMMTYPE   Other Central City Suburban
# PROPWLTH        $355,684 to < $378,489
# TAXRATE               $1.4272 and over
#
# [137 rows x 1 columns]

# %%
#It looks like there is no missing data for Cleburne ISD
[datapoint for datapoint in list(cleburne.iloc[:,0]) if datapoint == '.']
# Out:
# []

# %%
snapshotcolnames[:8]
# Out:
# ['DISTNAME',
#  'DISTRICT #',
#  'DZCNTYNM',
#  'REGION',
#  'DZRATING',
#  'DZCAMPUS',
#  'total students',
#  '4. Students % African American: ']

# %%
colnames = [i for i in snapshot2019.columns]
colnames[:8]
# Out:
# ['DISTNAME',
#  'D',
#  'DZCNTYNM',
#  'REGION',
#  'DZRATING',
#  'DZCAMPUS',
#  'DPETALLC',
#  'DPETBLAP']

# %%
#I want to rename my columns to be more readable. 

renamecolumns = {}
snapshotcolnames2 = snapshotcolnames
for k in colnames:
    for v in snapshotcolnames2:
        renamecolumns[k] = v
        snapshotcolnames2.remove(v)
        break

# %%
renamecolumns
# Out:
# {'DISTNAME': 'DISTNAME',
#  'D': 'DISTRICT #',
#  'DZCNTYNM': 'DZCNTYNM',
#  'REGION': 'REGION',
#  'DZRATING': 'DZRATING',
#  'DZCAMPUS': 'DZCAMPUS',
#  'DPETALLC': 'total students',
#  'DPETBLAP': '4. Students % African American: ',
#  'DPETHISP': '5. Students % Hispanic: ',
#  'DPETWHIP': '6. Students % White:',
#  'DPETINDP': '7. Students % American Indian:',
#  'DPETASIP': '8. Students % Asian:',
#  'DPETPCIP': '9. Students % Pacific Islander:',
#  'DPETTWOP': '10. Students % Two or More Races:',
#  'DPETECOP': '11. Students % Economically Disadvantaged:',
#  'DPETLEPP': '12. Students % English Learners (EL):',
#  'DPETSPEP': '13. Students % Special Education:',
#  'DPETBILP': '14. Students % Bilingual/ESL Education:',
#  'DPETVOCP': '15. Students % Career and Technical Education:',
#  'DPETGIFP': '16. Students % Gifted and Talented Education:',
#  'DA0AT18R': '17. Attendance Rate (2017-18):',
#  'DA0912DR18R': '18. Annual Dropout Rate Gr. 9-12 (2017-18):',
#  'DAGC4X18R': '19. 4-Year Longitudinal Graduation Rate (Class of 2018):',
#  'DAGC5X17R': '20. 5-Year Longitudinal Graduation Rate (Class of 2017):',
#  'DAGC6X16R': '21. 6-Year Longitudinal Graduation Rate (Class of 2016):',
#  'DA0GR18N': '22. Annual Graduate Count (2017-18):',
#  'DA0GS18N': '23. Annual RHSP/DAP/FHSP-E/FHSP-DLA Graduate Count (2017-18):',
#  'DDA00A001S19R': 'staar all subjects approach',
#  'DDA00A001219R': 'staar all subjects meet',
#  'DDA00A001319R': 'staar all subjects master',
#  'DDA00AR01S19R': 'staar elar approach',
#  'DDA00AR01219R': 'staar elar meets',
#  'DDA00AR01319R': 'staar elar master',
#  'DDA00AW01S19R': 'staar write approach',
#  'DDA00AW01219R': 'staar write meet',
#  'DDA00AW01319R': 'staar write master',
#  'DDA00AM01S19R': 'staar math approach',
#  'DDA00AM01219R': 'staar math meet',
#  'DDA00AM01319R': 'staar math master',
#  'DDA00AC01S19R': 'staar science approach',
#  'DDA00AC01219R': 'staar science meet',
#  'DDA00AC01319R': 'staar science master',
#  'DDA00AS01S19R': 'staar social approach',
#  'DDA00AS01219R': 'staar social meet',
#  'DDA00AS01319R': 'staar social master',
#  'DDB00A001S19R': 'staar african approach',
#  'DDB00A001219R': 'staar african meet',
#  'DDB00A001319R': 'staar african master',
#  'DDH00A001S19R': 'staar hispanic approach',
#  'DDH00A001219R': 'staar hispanic meet',
#  'DDH00A001319R': 'staar hispanic master',
#  'DDW00A001S19R': 'staar white approach',
#  'DDW00A001219R': 'staar white meet',
#  'DDW00A001319R': 'staar white master',
#  'DDI00A001S19R': 'staar native approach',
#  'DDI00A001219R': 'staar native meet',
#  'DDI00A001319R': 'staar native master',
#  'DD300A001S19R': 'staar asian approach',
#  'DD300A001219R': 'staar asian meet',
#  'DD300A001319R': 'staar asian master',
#  'DD400A001S19R': 'staar pacific approach',
#  'DD400A001219R': 'staar pacific meet',
#  'DD400A001319R': 'staar pacific master',
#  'DD200A001S19R': '2+ race approach',
#  'DD200A001219R': '2+ race meet',
#  'DD200A001319R': '2+ race master',
#  'DDE00A001S19R': 'econ disad approach',
#  'DDE00A001219R': 'econ disad meet',
#  'DDE00A001319R': 'econ disad master',
#  'DA0CT18R': '38. SAT/ACT Results - % Tested (2017-2018):',
#  'DA0CC18R': '39. SAT/ACT Results - % At or Above Criterion (2017-2018): ',
#  'DA0CSA18R': '40. SAT - Average Score (2017-2018):',
#  'DA0CAA18R': '41. ACT - Average Score (2017-2018):',
#  'DPSATOFC': '42. Total Staff FTE:',
#  'DPSTTOFC': '43. Total Teacher FTE: ',
#  'DPSCTOFP': '44. Staff % Central Administration:',
#  'DPSSTOFP': '45. Staff % Campus Administration:',
#  'DPSUTOFP': '46. Staff % Professional Support:',
#  'DPSTTOFP': '47. Staff % Teachers:',
#  'DPSETOFP': '48. Staff % Educational Aides:',
#  'DPSXTOFP': '49. Staff % Auxiliary:',
#  'DPSCTOSA': '50. Average Central Administrative Salary:',
#  'DPSSTOSA': '51. Average Campus Administrative Salary:',
#  'DPSUTOSA': '52. Average Professional Support Staff Salary:',
#  'DPSTTOSA': '53. Average Teacher Salary:',
#  'DPSAMIFP': '54. Staff % Minority:',
#  'DPSAKIDR': '55. Number of Students Per Total Staff: ',
#  'DPSTKIDR': '56. Number of Students Per Teacher:',
#  'DPST05FP': '57. Teacher % With 5 or Fewer Years of Experience: ',
#  'DPSTEXPA': '58. Teacher Average Years of Experience:',
#  'DPSTADFP': '59. Teacher % With Advanced Degrees:',
#  'DPSTURNR': '60. Teacher Turnover Rate:',
#  'DPSTBLFP': '61. Teacher % African American:',
#  'DPSTHIFP': '62. Teacher % Hispanic:',
#  'DPSTWHFP': '63. Teacher % White:',
#  'DPSTO2FP': '64. Teacher % Other:',
#  'DPSTREFP': '65. Teacher % Regular Education:',
#  'DPSTSPFP': '66. Teacher % Special Education:',
#  'DPSTCOFP': '67. Teacher % Compensatory Education:',
#  'DPSTBIFP': '68. Teacher % Bilingual/ESL Education:',
#  'DPSTVOFP': '69. Teacher % Career and Technical Education:',
#  'DPSTGOFP': '70. Teacher % Other Education (Includes Gifted and Talented):',
#  'DPFVTOTK': '71. Taxable Value Per Pupil (2016 Tax Year):',
#  'DPFTADPR': '72. Locally Adopted Tax Rate (2017 Tax Year):',
#  'DPFRAALLT': '73. Total Operating and Other Revenue (2017-18):',
#  'DPFRAALLK': '74. Total Operating and Other Revenue Per Pupil:',
#  'DPFRAOPRT': '75. Total Operating Revenue (2017-18):',
#  'DPFRASTAP': '76. Operating Revenue % State:',
#  'DZRVLOCP': '77. Operating Revenue % Local and Other:',
#  'DPFRAFEDP': '78. Operating Revenue % Federal:',
#  'DPFRAORVT': '79. Total Other Revenue (2017-18):',
#  'DPFUNAB1T': '80. Fund Balance (For ISDs):',
#  'DPFUNA4T': '81. Net Assets (Charter Schools):',
#  'DPFEAALLT': '82. Total Actual Expenditures (2017-18): ',
#  'DPFEAOPFT': '83. Total Actual Operating Expenditures (2017-18):',
#  'DPFEAOPFK': '84. Total Actual Operating Expenditures Per Pupil:',
#  'DPFEAINSP': '85. Expenditure % Instructional:',
#  'DZEXADMP': '86. Expenditure % Central Administrative: ',
#  'DZEXADSP': '87. Expenditure % School Leadership:',
#  'DZEXPLAP': '88. Expenditure % Plant Services: ',
#  'DZEXOTHP': '89. Expenditure % Other Operating:',
#  'DPFEAINST': '90. Total Actual Instructional Expenditures (2017-2018):',
#  'DPFEAINSK': '91. Total Actual Instructional Expenditures Per Pupil:',
#  'DPFPAREGP': '92. Expenditures % Basic Education Services: ',
#  'DPFPASPEP': '93. Expenditures % Special Education:',
#  'DPFPACOMP': '94. Expenditures % State Compensatory Education:',
#  'DPFPABILP': '95. Expenditures % Bilingual/ESL Education:',
#  'DPFPAVOCP': '96. Expenditures % Career and Technical Education:',
#  'DPFPAGIFP': '97. Expenditures % Gifted and Talented Education:',
#  'DPFPAATHP': '98. Expenditures % Athletics/Related Activities:',
#  'DPFPAHSAP': '99. Expenditures % High School Allotment:',
#  'DPFPREKP': '100. Expenditures % Prekindergarten:',
#  'DPFPAOTHP': '101. Expenditures % Un-Allocated:',
#  'DISTSIZE': 'DISTSIZE',
#  'COMMTYPE': 'COMMTYPE',
#  'PROPWLTH': 'PROPWLTH',
#  'TAXRATE': 'TAXRATE'}

# %%
readablesnapshot = snapshot2019.rename(renamecolumns, axis=1)

# %%
readablesnapshot.head()
# Out:
#         DISTNAME  DISTRICT #      DZCNTYNM  REGION DZRATING  DZCAMPUS  \
# 0     CAYUGA ISD        1902  001 ANDERSON       7        A         3
# 1    ELKHART ISD        1903  001 ANDERSON       7        A         5
# 2  FRANKSTON ISD        1904  001 ANDERSON       7        B         3
# 3     NECHES ISD        1906  001 ANDERSON       7        A         2
# 4  PALESTINE ISD        1907  001 ANDERSON       7        B         6
#
#    total students  4. Students % African American:   5. Students % Hispanic:   \
# 0             564                               3.5                       6.7
# 1            1254                               5.4                      11.3
# 2             803                               8.2                       8.2
# 3             366                               8.5                      13.9
# 4            3389                              26.6                      41.2
#
#    6. Students % White:  ...  \
# 0                  84.8  ...
# 1                  78.1  ...
# 2                  78.2  ...
# 3                  73.2  ...
# 4                  27.5  ...
#
#    96. Expenditures % Career and Technical Education:  \
# 0                                                2.8
# 1                                                7.8
# 2                                                6.9
# 3                                                  4
# 4                                                3.9
#
#    97. Expenditures % Gifted and Talented Education:  \
# 0                                                0.1
# 1                                                0.1
# 2                                                0.1
# 3                                                0.3
# 4                                                0.2
#
#    98. Expenditures % Athletics/Related Activities:  \
# 0                                               3.6
# 1                                               3.4
# 2                                               7.3
# 3                                                 0
# 4                                               3.4
#
#    99. Expenditures % High School Allotment:  \
# 0                                        0.6
# 1                                          1
# 2                                          1
# 3                                        1.2
# 4                                        0.7
#
#    100. Expenditures % Prekindergarten:  101. Expenditures % Un-Allocated:  \
# 0                                   0.3                               20.8
# 1                                     0                               25.7
# 2                                   1.1                               28.2
# 3                                   0.5                               35.1
# 4                                   2.1                               28.3
#
#          DISTSIZE                 COMMTYPE                PROPWLTH  \
# 0      500 to 999                    Rural  $442,675 to < $456,961
# 1  1,000 to 1,599  Non-metropolitan Stable  $164,221 to < $208,918
# 2      500 to 999                    Rural  $272,534 to < $299,260
# 3       Under 500                    Rural  $272,534 to < $299,260
# 4  3,000 to 4,999         Independent Town  $299,260 to < $316,695
#
#                     TAXRATE
# 0             Under $1.1701
# 1  $1.3050 to under $1.4272
# 2          $1.4272 and over
# 3          $1.4272 and over
# 4          $1.4272 and over
#
# [5 rows x 137 columns]

# %%
#Let's see how many missing values there are by column. Missing values are noted here with a '.'
#Note

# %%
renamecolumns['DA0912DR18R']
# Out:
# '18. Annual Dropout Rate Gr. 9-12 (2017-18):'

# %%
test = readablesnapshot.iloc[:40,21]

# %%
test.replace('.',np.NaN)
# Out:
# 0       0
# 1       0
# 2     0.4
# 3     0.9
# 4       0
# 5     0.4
# 6       0
# 7     0.5
# 8     0.4
# 9     1.3
# 10    1.4
# 11    1.2
# 12    0.8
# 13    1.6
# 14    0.2
# 15    1.9
# 16      0
# 17      0
# 18      0
# 19    1.8
# 20      0
# 21    0.9
# 22    2.1
# 23    0.8
# 24    0.5
# 25    0.8
# 26      2
# 27      0
# 28      0
# 29      1
# 30    1.4
# 31    0.3
# 32    1.8
# 33    0.3
# 34      0
# 35    1.7
# 36    NaN
# 37    1.6
# 38    NaN
# 39    3.6
# Name: 18. Annual Dropout Rate Gr. 9-12 (2017-18):, dtype: object

# %%
# replacing '.' with nan for simpler standard analysis
readablesnapshot.replace('.',np.NaN, inplace=True)

# %%
missing = pd.concat([readablesnapshot.isnull().sum(), 100 * readablesnapshot.isnull().mean()], axis=1)

# %%
missing.columns=['count', '%']
missing.sort_values(by='count')
# Out:
#                                                count          %
# DISTNAME                                           0   0.000000
# COMMTYPE                                           0   0.000000
# DISTSIZE                                           0   0.000000
# PROPWLTH                                           0   0.000000
# 16. Students % Gifted and Talented Education:      0   0.000000
# ...                                              ...        ...
# staar native meet                                438  36.469609
# staar native approach                            438  36.469609
# staar pacific master                             800  66.611157
# staar pacific meet                               800  66.611157
# staar pacific approach                           800  66.611157
#
# [137 rows x 2 columns]

# %%
#Dropping the ones with complete data to get a better picture
missingshort = missing[missing['count'] > 10]
missingshort
# Out:
#                                                     count          %
# 18. Annual Dropout Rate Gr. 9-12 (2017-18):           113   9.408826
# 19. 4-Year Longitudinal Graduation Rate (Class ...    143  11.906744
# 20. 5-Year Longitudinal Graduation Rate (Class ...    150  12.489592
# 21. 6-Year Longitudinal Graduation Rate (Class ...    155  12.905912
# 22. Annual Graduate Count (2017-18):                  132  10.990841
# 23. Annual RHSP/DAP/FHSP-E/FHSP-DLA Graduate Co...    132  10.990841
# staar write approach                                   32   2.664446
# staar write meet                                       32   2.664446
# staar write master                                     32   2.664446
# staar social approach                                  38   3.164030
# staar social meet                                      38   3.164030
# staar social master                                    38   3.164030
# staar african approach                                164  13.655287
# staar african meet                                    164  13.655287
# staar african master                                  164  13.655287
# staar white approach                                   23   1.915071
# staar white meet                                       23   1.915071
# staar white master                                     23   1.915071
# staar native approach                                 438  36.469609
# staar native meet                                     438  36.469609
# staar native master                                   438  36.469609
# staar asian approach                                  406  33.805162
# staar asian meet                                      406  33.805162
# staar asian master                                    406  33.805162
# staar pacific approach                                800  66.611157
# staar pacific meet                                    800  66.611157
# staar pacific master                                  800  66.611157
# 2+ race approach                                      132  10.990841
# 2+ race meet                                          132  10.990841
# 2+ race master                                        132  10.990841
# 38. SAT/ACT Results - % Tested (2017-2018):           125  10.407993
# 39. SAT/ACT Results - % At or Above Criterion (...    134  11.157369
# 40. SAT - Average Score (2017-2018):                  205  17.069109
# 41. ACT - Average Score (2017-2018):                  167  13.905079
# 51. Average Campus Administrative Salary:              14   1.165695
# 52. Average Professional Support Staff Salary:         60   4.995837

# %% [markdown]
# It looks like most of the missing data has to do with staar scores for certain demographics. I might imagine that these values represent areas with little or no representation of the respective race, but since this database also uses zeros for those columns I think it is more accurate to suggest that the data is missing.
#
# Since racial staar data might not be useful for determining actionable steps to increasing the graduation rate I'll drop those columns. I'll also drop multi-year graduation rate since it's missing too much data to be useful. I'll keep SAT and ACT averages because those seem like important factors for determining graduation rates. If the districts with missing SAT averages are usually the same districts with missing ACT averages I'll just drop those rows. Otherwise I'll use the mean.

# %%
removestaarlist = ['staar african approach',
'staar african meet',
'staar african master',
'staar hispanic approach',
'staar hispanic meet',
'staar hispanic master',
'staar white approach',
'staar white meet',
'staar white master',
'staar native approach',
'staar native meet',
'staar native master',
'staar asian approach',
'staar asian meet',
'staar asian master',
'staar pacific approach',
'staar pacific meet',
'staar pacific master',
'2+ race approach',
'2+ race meet',
'2+ race master',
'19. 4-Year Longitudinal Graduation Rate (Class of 2018):',
'20. 5-Year Longitudinal Graduation Rate (Class of 2017):',
'21. 6-Year Longitudinal Graduation Rate (Class of 2016):']
readablesnapshot.drop(columns=removestaarlist, inplace=True)

# %%
missing = pd.concat([readablesnapshot.isnull().sum(), 100 * readablesnapshot.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by='count')
missing[missing['%']>1 ]
# Out:
#                                                     count          %
# 18. Annual Dropout Rate Gr. 9-12 (2017-18):           113   9.408826
# 22. Annual Graduate Count (2017-18):                  132  10.990841
# 23. Annual RHSP/DAP/FHSP-E/FHSP-DLA Graduate Co...    132  10.990841
# staar write approach                                   32   2.664446
# staar write meet                                       32   2.664446
# staar write master                                     32   2.664446
# staar social approach                                  38   3.164030
# staar social meet                                      38   3.164030
# staar social master                                    38   3.164030
# 38. SAT/ACT Results - % Tested (2017-2018):           125  10.407993
# 39. SAT/ACT Results - % At or Above Criterion (...    134  11.157369
# 40. SAT - Average Score (2017-2018):                  205  17.069109
# 41. ACT - Average Score (2017-2018):                  167  13.905079
# 51. Average Campus Administrative Salary:              14   1.165695
# 52. Average Professional Support Staff Salary:         60   4.995837

# %%
#Note to self: Now you have to go through each item on the above list and decide how to handle the missing data on a case by
#case basis. Then you'll have to go through the entire dataset and decide whether to use means for missing data, a minimum value
#, or drop the row altogether. It might be dangerious to start dropping every row that's missing a value. There are very few 
# features that have no missing values.

# %%
#The dataset was too unwieldy. I've broken it down to examine the chunks and fix missing data.
rss1 = readablesnapshot.iloc[:,0:20]
rss2 = readablesnapshot.iloc[:,20:40]
rss3 = readablesnapshot.iloc[:,40:60]
rss4 = readablesnapshot.iloc[:,60:80]
rss5 = readablesnapshot.iloc[:,80:100]
rss6 = readablesnapshot.iloc[:,100:]
#rss1.head()
missingrss1 = pd.concat([rss1.isnull().sum(), 100 * rss1.isnull().mean()], axis=1)
missingrss1.columns=['count', '%']
missingrss1.sort_values(by='count')
missingrss1
#first chunk has no missing data
# Out:
#                                                 count    %
# DISTNAME                                            0  0.0
# DISTRICT #                                          0  0.0
# DZCNTYNM                                            0  0.0
# REGION                                              0  0.0
# DZRATING                                            0  0.0
# DZCAMPUS                                            0  0.0
# total students                                      0  0.0
# 4. Students % African American:                     0  0.0
# 5. Students % Hispanic:                             0  0.0
# 6. Students % White:                                0  0.0
# 7. Students % American Indian:                      0  0.0
# 8. Students % Asian:                                0  0.0
# 9. Students % Pacific Islander:                     0  0.0
# 10. Students % Two or More Races:                   0  0.0
# 11. Students % Economically Disadvantaged:          0  0.0
# 12. Students % English Learners (EL):               0  0.0
# 13. Students % Special Education:                   0  0.0
# 14. Students % Bilingual/ESL Education:             0  0.0
# 15. Students % Career and Technical Education:      0  0.0
# 16. Students % Gifted and Talented Education:       0  0.0

# %%
rss1.dtypes
# Out:
# DISTNAME                                           object
# DISTRICT #                                          int64
# DZCNTYNM                                           object
# REGION                                              int64
# DZRATING                                           object
# DZCAMPUS                                            int64
# total students                                      int64
# 4. Students % African American:                   float64
# 5. Students % Hispanic:                           float64
# 6. Students % White:                              float64
# 7. Students % American Indian:                    float64
# 8. Students % Asian:                              float64
# 9. Students % Pacific Islander:                   float64
# 10. Students % Two or More Races:                 float64
# 11. Students % Economically Disadvantaged:        float64
# 12. Students % English Learners (EL):             float64
# 13. Students % Special Education:                 float64
# 14. Students % Bilingual/ESL Education:           float64
# 15. Students % Career and Technical Education:    float64
# 16. Students % Gifted and Talented Education:     float64
# dtype: object

# %%
missingrss2 = pd.concat([rss2.isnull().sum(), 100 * rss2.isnull().mean()], axis=1)
missingrss2.columns=['count', '%']
missingrss2.sort_values(by='count')
missingrss2
# Out:
#                                                     count          %
# 17. Attendance Rate (2017-18):                          6   0.499584
# 18. Annual Dropout Rate Gr. 9-12 (2017-18):           113   9.408826
# 22. Annual Graduate Count (2017-18):                  132  10.990841
# 23. Annual RHSP/DAP/FHSP-E/FHSP-DLA Graduate Co...    132  10.990841
# staar all subjects approach                             2   0.166528
# staar all subjects meet                                 2   0.166528
# staar all subjects master                               2   0.166528
# staar elar approach                                     2   0.166528
# staar elar meets                                        2   0.166528
# staar elar master                                       2   0.166528
# staar write approach                                   32   2.664446
# staar write meet                                       32   2.664446
# staar write master                                     32   2.664446
# staar math approach                                     2   0.166528
# staar math meet                                         2   0.166528
# staar math master                                       2   0.166528
# staar science approach                                  8   0.666112
# staar science meet                                      8   0.666112
# staar science master                                    8   0.666112
# staar social approach                                  38   3.164030

# %%
rss2.dtypes.head(3)
#for some reason at this point all the datatypes switch to objects. Is it because of the missing values?
# Out:
# 17. Attendance Rate (2017-18):                 object
# 18. Annual Dropout Rate Gr. 9-12 (2017-18):    object
# 22. Annual Graduate Count (2017-18):           object
# dtype: object

# %%
rss2['17. Attendance Rate (2017-18):'] = rss2['17. Attendance Rate (2017-18):'].astype(float)

# %%
rss2['17. Attendance Rate (2017-18):'].dtypes
# Out:
# dtype('float64')

# %%
attendmean = rss2['17. Attendance Rate (2017-18):'].mean()
rss2['17. Attendance Rate (2017-18):'].fillna(attendmean, inplace=True)
rss2.dtypes.head(3)
#looks like it
# Out:
# 17. Attendance Rate (2017-18):                 float64
# 18. Annual Dropout Rate Gr. 9-12 (2017-18):     object
# 22. Annual Graduate Count (2017-18):            object
# dtype: object

# %%
#according to kaggle unless the amount of missing data is significant I should just replace with the mean.
#https://www.kaggle.com/questions-and-answers/205588
# I will create a list of all the columns where the amount of missing data is greater than 35% and remove those columns.
#I will use the means in each column to then replace missing values.

# %%
missing.head()
# Out:
#             count    %
# DISTNAME        0  0.0
# DISTRICT #      0  0.0
# DZCNTYNM        0  0.0
# REGION          0  0.0
# DZRATING        0  0.0

# %%
missing[missing['%']>10 ]
# Out:
#                                                     count          %
# 22. Annual Graduate Count (2017-18):                  132  10.990841
# 23. Annual RHSP/DAP/FHSP-E/FHSP-DLA Graduate Co...    132  10.990841
# 38. SAT/ACT Results - % Tested (2017-2018):           125  10.407993
# 39. SAT/ACT Results - % At or Above Criterion (...    134  11.157369
# 40. SAT - Average Score (2017-2018):                  205  17.069109
# 41. ACT - Average Score (2017-2018):                  167  13.905079

# %%
readablesnapshot[readablesnapshot['41. ACT - Average Score (2017-2018):'].isnull()]
# Out:
#                                 DISTNAME  DISTRICT #        DZCNTYNM  REGION  \
# 34                            MCDADE ISD       11905     011 BASTROP      13
# 36      ST MARY'S ACADEMY CHARTER SCHOOL       13801         013 BEE       2
# 38                            PAWNEE ISD       13902         013 BEE       2
# 45                          BARTLETT ISD       14902        014 BELL      13
# 56     SCHOOL OF EXCELLENCE IN EDUCATION       15806       015 BEXAR      20
# ...                                  ...         ...             ...     ...
# 1125                        RAVEN SCHOOL      236801      236 WALKER       6
# 1126  SAM HOUSTON STATE UNIVERSITY CHART      236802      236 WALKER       6
# 1154                         HARROLD ISD      244901   244 WILBARGER       9
# 1162         GOODWATER MONTESSORI SCHOOL      246802  246 WILLIAMSON      13
# 1173                        COUPLAND ISD      246914  246 WILLIAMSON      13
#
#        DZRATING  DZCAMPUS  total students  4. Students % African American:   \
# 34            B         2             382                               1.3
# 36            B         1             430                               1.6
# 38            B         1             318                               1.3
# 45            C         1             342                              11.7
# 56            B         4             649                              27.3
# ...         ...       ...             ...                               ...
# 1125  Not Rated         1             103                              19.4
# 1126          B         1             299                              23.4
# 1154          B         1             107                               0.0
# 1162          C         1             349                               3.7
# 1173          A         1             169                               1.2
#
#       5. Students % Hispanic:   6. Students % White:  ...  \
# 34                        47.1                  50.8  ...
# 36                        79.3                  14.7  ...
# 38                        78.0                  19.2  ...
# 45                        65.8                  19.6  ...
# 56                        66.7                   2.3  ...
# ...                        ...                   ...  ...
# 1125                      47.6                  28.2  ...
# 1126                      21.1                  47.2  ...
# 1154                      34.6                  61.7  ...
# 1162                      28.1                  54.2  ...
# 1173                      27.8                  66.3  ...
#
#       96. Expenditures % Career and Technical Education:  \
# 34                                                  2.1
# 36                                                    0
# 38                                                    0
# 45                                                  3.2
# 56                                                  0.6
# ...                                                 ...
# 1125                                               35.5
# 1126                                                  0
# 1154                                                3.1
# 1162                                                  0
# 1173                                                  0
#
#       97. Expenditures % Gifted and Talented Education:  \
# 34                                                  0.5
# 36                                                  0.3
# 38                                                  0.1
# 45                                                  0.4
# 56                                                    0
# ...                                                 ...
# 1125                                                  0
# 1126                                                  0
# 1154                                                0.2
# 1162                                                0.1
# 1173                                                0.3
#
#       98. Expenditures % Athletics/Related Activities:  \
# 34                                                   1
# 36                                                   0
# 38                                                   1
# 45                                                 6.5
# 56                                                 0.4
# ...                                                ...
# 1125                                               0.2
# 1126                                                 0
# 1154                                               2.3
# 1162                                                 0
# 1173                                               0.6
#
#       99. Expenditures % High School Allotment:  \
# 34                                          0.3
# 36                                            0
# 38                                            0
# 45                                          1.1
# 56                                            0
# ...                                         ...
# 1125                                        1.4
# 1126                                          0
# 1154                                        0.7
# 1162                                          0
# 1173                                          0
#
#       100. Expenditures % Prekindergarten:  101. Expenditures % Un-Allocated:  \
# 34                                     5.1                               36.4
# 36                                       0                               34.8
# 38                                    35.2                               29.6
# 45                                       0                               35.3
# 56                                     2.6                               48.8
# ...                                    ...                                ...
# 1125                                     0                                 20
# 1126                                     0                               24.9
# 1154                                     0                               36.4
# 1162                                   0.5                               38.2
# 1173                                     0                               39.4
#
#         DISTSIZE                       COMMTYPE                PROPWLTH  \
# 34     Under 500  Non-metropolitan Fast Growing  $250,173 to < $272,534
# 36     Under 500                       Charters     Non-taxing entities
# 38     Under 500  Non-metropolitan Fast Growing       $786,525 and over
# 45     Under 500                          Rural  $299,260 to < $316,695
# 56    500 to 999                       Charters     Non-taxing entities
# ...          ...                            ...                     ...
# 1125   Under 500                       Charters     Non-taxing entities
# 1126   Under 500                       Charters     Non-taxing entities
# 1154   Under 500                          Rural  $413,609 to < $442,675
# 1162   Under 500                       Charters     Non-taxing entities
# 1173   Under 500                          Rural  $378,489 to < $413,609
#
#                        TAXRATE
# 34               Under $1.1701
# 36         Non-taxing entities
# 38    $1.1701 to under $1.3050
# 45               Under $1.1701
# 56         Non-taxing entities
# ...                        ...
# 1125       Non-taxing entities
# 1126       Non-taxing entities
# 1154             Under $1.1701
# 1162       Non-taxing entities
# 1173             Under $1.1701
#
# [167 rows x 113 columns]

# %%
removesatact = readablesnapshot['40. SAT - Average Score (2017-2018):'].isnull() & readablesnapshot['41. ACT - Average Score (2017-2018):'].isnull()

# %%
readablesnapshot = readablesnapshot[~removesatact]

# %%
#Removed districts with no SAT or ACT scores. I'll use the mean to fill in the rest of the values. 
missing = pd.concat([readablesnapshot.isnull().sum(), 100 * readablesnapshot.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by='count')
missing[missing['%']>0 ]
# Out:
#                                                     count         %
# 18. Annual Dropout Rate Gr. 9-12 (2017-18):             3  0.281162
# 22. Annual Graduate Count (2017-18):                    7  0.656045
# 23. Annual RHSP/DAP/FHSP-E/FHSP-DLA Graduate Co...      7  0.656045
# staar write approach                                   24  2.249297
# staar write meet                                       24  2.249297
# staar write master                                     24  2.249297
# econ disad approach                                     3  0.281162
# econ disad meet                                         3  0.281162
# econ disad master                                       3  0.281162
# 40. SAT - Average Score (2017-2018):                   71  6.654171
# 41. ACT - Average Score (2017-2018):                   33  3.092784
# 42. Total Staff FTE:                                    1  0.093721
# 43. Total Teacher FTE:                                  1  0.093721
# 44. Staff % Central Administration:                     1  0.093721
# 45. Staff % Campus Administration:                      1  0.093721
# 46. Staff % Professional Support:                       1  0.093721
# 47. Staff % Teachers:                                   1  0.093721
# 48. Staff % Educational Aides:                          1  0.093721
# 49. Staff % Auxiliary:                                  1  0.093721
# 50. Average Central Administrative Salary:              4  0.374883
# 51. Average Campus Administrative Salary:               9  0.843486
# 52. Average Professional Support Staff Salary:         25  2.343018
# 53. Average Teacher Salary:                             3  0.281162
# 54. Staff % Minority:                                   1  0.093721
# 55. Number of Students Per Total Staff:                 1  0.093721
# 56. Number of Students Per Teacher:                     1  0.093721
# 57. Teacher % With 5 or Fewer Years of Experien...      1  0.093721
# 58. Teacher Average Years of Experience:                1  0.093721
# 59. Teacher % With Advanced Degrees:                    1  0.093721
# 60. Teacher Turnover Rate:                              2  0.187441
# 61. Teacher % African American:                         1  0.093721
# 62. Teacher % Hispanic:                                 1  0.093721
# 63. Teacher % White:                                    1  0.093721
# 64. Teacher % Other:                                    1  0.093721
# 65. Teacher % Regular Education:                        1  0.093721
# 66. Teacher % Special Education:                        1  0.093721
# 67. Teacher % Compensatory Education:                   1  0.093721
# 68. Teacher % Bilingual/ESL Education:                  1  0.093721
# 69. Teacher % Career and Technical Education:           1  0.093721
# 70. Teacher % Other Education (Includes Gifted ...      1  0.093721

# %%
len(missing)
# Out:
# 113

# %%
missingwithindex = missing[missing['count']>0]

# %%
missingwithindex.reset_index(inplace=True)
missingwithindex
# Out:
#                                                 index  count         %
# 0         18. Annual Dropout Rate Gr. 9-12 (2017-18):      3  0.281162
# 1                22. Annual Graduate Count (2017-18):      7  0.656045
# 2   23. Annual RHSP/DAP/FHSP-E/FHSP-DLA Graduate C...      7  0.656045
# 3                                staar write approach     24  2.249297
# 4                                    staar write meet     24  2.249297
# 5                                  staar write master     24  2.249297
# 6                                 econ disad approach      3  0.281162
# 7                                     econ disad meet      3  0.281162
# 8                                   econ disad master      3  0.281162
# 9                40. SAT - Average Score (2017-2018):     71  6.654171
# 10               41. ACT - Average Score (2017-2018):     33  3.092784
# 11                               42. Total Staff FTE:      1  0.093721
# 12                            43. Total Teacher FTE:       1  0.093721
# 13                44. Staff % Central Administration:      1  0.093721
# 14                 45. Staff % Campus Administration:      1  0.093721
# 15                  46. Staff % Professional Support:      1  0.093721
# 16                              47. Staff % Teachers:      1  0.093721
# 17                     48. Staff % Educational Aides:      1  0.093721
# 18                             49. Staff % Auxiliary:      1  0.093721
# 19         50. Average Central Administrative Salary:      4  0.374883
# 20          51. Average Campus Administrative Salary:      9  0.843486
# 21     52. Average Professional Support Staff Salary:     25  2.343018
# 22                        53. Average Teacher Salary:      3  0.281162
# 23                              54. Staff % Minority:      1  0.093721
# 24           55. Number of Students Per Total Staff:       1  0.093721
# 25                56. Number of Students Per Teacher:      1  0.093721
# 26  57. Teacher % With 5 or Fewer Years of Experie...      1  0.093721
# 27           58. Teacher Average Years of Experience:      1  0.093721
# 28               59. Teacher % With Advanced Degrees:      1  0.093721
# 29                         60. Teacher Turnover Rate:      2  0.187441
# 30                    61. Teacher % African American:      1  0.093721
# 31                            62. Teacher % Hispanic:      1  0.093721
# 32                               63. Teacher % White:      1  0.093721
# 33                               64. Teacher % Other:      1  0.093721
# 34                   65. Teacher % Regular Education:      1  0.093721
# 35                   66. Teacher % Special Education:      1  0.093721
# 36              67. Teacher % Compensatory Education:      1  0.093721
# 37             68. Teacher % Bilingual/ESL Education:      1  0.093721
# 38      69. Teacher % Career and Technical Education:      1  0.093721
# 39  70. Teacher % Other Education (Includes Gifted...      1  0.093721

# %%
len(missingwithindex)
# Out:
# 40

# %%
missingwithindex.columns = ['feature', 'count', 'percent']

# %%
missingcolnames = []
for row in missingwithindex['feature']:
    missingcolnames.append(row)

# %%
missingcolnames
# Out:
# ['18. Annual Dropout Rate Gr. 9-12 (2017-18):',
#  '22. Annual Graduate Count (2017-18):',
#  '23. Annual RHSP/DAP/FHSP-E/FHSP-DLA Graduate Count (2017-18):',
#  'staar write approach',
#  'staar write meet',
#  'staar write master',
#  'econ disad approach',
#  'econ disad meet',
#  'econ disad master',
#  '40. SAT - Average Score (2017-2018):',
#  '41. ACT - Average Score (2017-2018):',
#  '42. Total Staff FTE:',
#  '43. Total Teacher FTE: ',
#  '44. Staff % Central Administration:',
#  '45. Staff % Campus Administration:',
#  '46. Staff % Professional Support:',
#  '47. Staff % Teachers:',
#  '48. Staff % Educational Aides:',
#  '49. Staff % Auxiliary:',
#  '50. Average Central Administrative Salary:',
#  '51. Average Campus Administrative Salary:',
#  '52. Average Professional Support Staff Salary:',
#  '53. Average Teacher Salary:',
#  '54. Staff % Minority:',
#  '55. Number of Students Per Total Staff: ',
#  '56. Number of Students Per Teacher:',
#  '57. Teacher % With 5 or Fewer Years of Experience: ',
#  '58. Teacher Average Years of Experience:',
#  '59. Teacher % With Advanced Degrees:',
#  '60. Teacher Turnover Rate:',
#  '61. Teacher % African American:',
#  '62. Teacher % Hispanic:',
#  '63. Teacher % White:',
#  '64. Teacher % Other:',
#  '65. Teacher % Regular Education:',
#  '66. Teacher % Special Education:',
#  '67. Teacher % Compensatory Education:',
#  '68. Teacher % Bilingual/ESL Education:',
#  '69. Teacher % Career and Technical Education:',
#  '70. Teacher % Other Education (Includes Gifted and Talented):']

# %%
readablesnapshot[missingcolnames] = readablesnapshot[missingcolnames].astype(float)

# %%
missingcolmeans = []
for miss in missingcolnames:
    missingcolmeans.append(readablesnapshot[miss].mean())

# %%
replacewithmeans = dict(zip(missingcolnames, missingcolmeans))

# %%
for i in missingcolnames:
    readablesnapshot[i].fillna(replacewithmeans[i], inplace=True)

# %%
missing = pd.concat([readablesnapshot.isnull().sum(), 100 * readablesnapshot.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by='count')
missing[missing['%']>0 ]
# Out:
# Empty DataFrame
# Columns: [count, %]
# Index: []

# %%
readablesnapshot.iloc[:5,-5:]
# Out:
#   101. Expenditures % Un-Allocated:        DISTSIZE                 COMMTYPE  \
# 0                              20.8      500 to 999                    Rural
# 1                              25.7  1,000 to 1,599  Non-metropolitan Stable
# 2                              28.2      500 to 999                    Rural
# 3                              35.1       Under 500                    Rural
# 4                              28.3  3,000 to 4,999         Independent Town
#
#                  PROPWLTH                   TAXRATE
# 0  $442,675 to < $456,961             Under $1.1701
# 1  $164,221 to < $208,918  $1.3050 to under $1.4272
# 2  $272,534 to < $299,260          $1.4272 and over
# 3  $272,534 to < $299,260          $1.4272 and over
# 4  $299,260 to < $316,695          $1.4272 and over

# %%
#No more missing values!!!
#Now to select the categorical features and make sure they are in a form I can analyse. 
readablesnapshot.iloc[:,8:-4] = readablesnapshot.iloc[:,8:-4].astype(float)

# %%
sizes = []
for size in readablesnapshot['DISTSIZE']:
    sizes.append(size)
# function to get unique values (this code line adapted from https://www.geeksforgeeks.org/python-get-unique-values-list/)
def unique(list1):
 
    # initialize a null list
    unique_list = []
     
    # traverse for all elements
    for x in list1:
        # check if exists in unique_list or not
        if x not in unique_list:
            unique_list.append(x)
    # print list
    for x in unique_list:
        print (x)
unique(sizes)
#It appears district size is already set up in categories
# Out:
# 500 to 999
# 1,000 to 1,599
# Under 500
# 3,000 to 4,999
# 1,600 to 2,999
# 5,000 to 9,999
# 10,000 to 24,999
# 25,000 to 49,999
# 50,000 and over

# %%
#step1: select all rows with taxes
#step2: remove all $ and ,
#step3: remove "to < "
#step4: str.split(" ")
#step5: (propwlth[0] + propwlth[1])/2 for approx average wealth in district
readablesnapshot['PROPWLTH'].head()
# Out:
# 0    $442,675 to < $456,961
# 1    $164,221 to < $208,918
# 2    $272,534 to < $299,260
# 3    $272,534 to < $299,260
# 4    $299,260 to < $316,695
# Name: PROPWLTH, dtype: object

# %%
for line in readablesnapshot['PROPWLTH']:
    if line == 'Non-taxing entities':
        continue
    else:
        new_string = re.sub(r"$|,", "test", line)
        line = new_string
#line = re.sub('[!@#$]', '', line)

# %%
readablesnapshot['PROPWLTH'].head()
# Out:
# 0    $442,675 to < $456,961
# 1    $164,221 to < $208,918
# 2    $272,534 to < $299,260
# 3    $272,534 to < $299,260
# 4    $299,260 to < $316,695
# Name: PROPWLTH, dtype: object

# %%
readablesnapshot['PROPWLTH'][4][0]
# Out:
# '$'

# %%
for line in readablesnapshot['PROPWLTH']:
    if line == 'Non-taxing entities':
        continue
    elif line[0] == 'U' or line[9] == 'a': 
        
        print(line)
        
    #else:
        #del line[0]
        #del line[4]
        #del line[8:15]
# Out:
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# Under $123,158
# Under $123,158
# Under $123,158
# $786,525 and over
# $786,525 and over
# $786,525 and over
# Under $123,158
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# Under $123,158
# Under $123,158
# $786,525 and over
# Under $123,158
# Under $123,158
# Under $123,158
# $786,525 and over
# Under $123,158
# $786,525 and over
# Under $123,158
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# Under $123,158
# Under $123,158
# Under $123,158
# Under $123,158
# Under $123,158
# Under $123,158
# Under $123,158
# Under $123,158
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# Under $123,158
# Under $123,158
# Under $123,158
# Under $123,158
# Under $123,158
# Under $123,158
# Under $123,158
# Under $123,158
# Under $123,158
# $786,525 and over
# $786,525 and over
# $786,525 and over
# Under $123,158
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# Under $123,158
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# Under $123,158
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# Under $123,158
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# Under $123,158
# Under $123,158
# $786,525 and over
# $786,525 and over
# $786,525 and over
# Under $123,158
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# Under $123,158
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# Under $123,158
# $786,525 and over
# Under $123,158
# $786,525 and over
# $786,525 and over
# $786,525 and over
# Under $123,158
# Under $123,158
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over
# $786,525 and over

# %%
for line in readablesnapshot['PROPWLTH']:
    if line == 'Non-taxing entities' or line[0] == 'U' or line[9] == 'a':
        continue
    else:
        line = line.replace('$', '')

# %%
readablesnapshot['PROPWLTH'].head()
# Out:
# 0    $442,675 to < $456,961
# 1    $164,221 to < $208,918
# 2    $272,534 to < $299,260
# 3    $272,534 to < $299,260
# 4    $299,260 to < $316,695
# Name: PROPWLTH, dtype: object

# %%
for row in readablesnapshot['PROPWLTH']:
    if row == 'Non-taxing entities' or row[0] == 'U' or row[9] == 'a':
        continue
    else:
        #print(row[1:4]+row[5:9]+row[15:18]+row[19:])
        row = 'test'

# %%
readablesnapshot['PROPWLTH'].head()
# Out:
# 0    $442,675 to < $456,961
# 1    $164,221 to < $208,918
# 2    $272,534 to < $299,260
# 3    $272,534 to < $299,260
# 4    $299,260 to < $316,695
# Name: PROPWLTH, dtype: object

# %%
#Moving on from categorical data for now. 
#Next examining data to make sure it makes sense.
description = readablesnapshot.describe().T

# %%
description.columns
# Out:
# Index(['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max'], dtype='object')

# %%
description[:20]
# Out:
#                                                  count           mean  \
# DISTRICT #                                      1067.0  123953.454545
# REGION                                          1067.0      10.556701
# DZCAMPUS                                        1067.0       8.089972
# total students                                  1067.0    5023.809747
# 4. Students % African American:                 1067.0       7.518650
# 5. Students % Hispanic:                         1067.0      41.991753
# 6. Students % White:                            1067.0      46.145361
# 7. Students % American Indian:                  1067.0       0.382099
# 8. Students % Asian:                            1067.0       1.439925
# 9. Students % Pacific Islander:                 1067.0       0.098500
# 10. Students % Two or More Races:               1067.0       2.424930
# 11. Students % Economically Disadvantaged:      1067.0      60.433833
# 12. Students % English Learners (EL):           1067.0      10.606842
# 13. Students % Special Education:               1067.0      10.212371
# 14. Students % Bilingual/ESL Education:         1067.0      10.483880
# 15. Students % Career and Technical Education:  1067.0      30.471321
# 16. Students % Gifted and Talented Education:   1067.0       5.789503
# 17. Attendance Rate (2017-18):                  1067.0      95.422774
# 18. Annual Dropout Rate Gr. 9-12 (2017-18):     1067.0       0.887688
# 22. Annual Graduate Count (2017-18):            1067.0     327.016981
#
#                                                          std     min      25%  \
# DISTRICT #                                      73363.631071  1902.0  61852.5
# REGION                                              5.293569     1.0      7.0
# DZCAMPUS                                           17.592728     1.0      2.0
# total students                                  13631.436300    38.0    450.0
# 4. Students % African American:                    11.418823     0.0      0.7
# 5. Students % Hispanic:                            27.000286     1.8     19.6
# 6. Students % White:                               26.971945     0.0     23.4
# 7. Students % American Indian:                      0.727346     0.0      0.0
# 8. Students % Asian:                                4.182495     0.0      0.1
# 9. Students % Pacific Islander:                     0.588362     0.0      0.0
# 10. Students % Two or More Races:                   1.831212     0.0      1.1
# 11. Students % Economically Disadvantaged:         19.841149     0.0     48.2
# 12. Students % English Learners (EL):              11.570510     0.0      2.7
# 13. Students % Special Education:                   2.913815     0.5      8.4
# 14. Students % Bilingual/ESL Education:            11.616365     0.0      2.6
# 15. Students % Career and Technical Education:      9.817365     0.0     26.2
# 16. Students % Gifted and Talented Education:       3.443078     0.0      3.7
# 17. Attendance Rate (2017-18):                      1.680145    76.4     95.0
# 18. Annual Dropout Rate Gr. 9-12 (2017-18):         2.102029     0.0      0.0
# 22. Annual Graduate Count (2017-18):              849.667161     1.0     31.0
#
#                                                      50%        75%       max
# DISTRICT #                                      113906.0  184903.50  254902.0
# REGION                                              11.0      15.00      20.0
# DZCAMPUS                                             3.0       6.00     279.0
# total students                                    1079.0    3265.00  209040.0
# 4. Students % African American:                      2.7      10.25      94.9
# 5. Students % Hispanic:                             36.3      60.30     100.0
# 6. Students % White:                                47.8      70.10      94.6
# 7. Students % American Indian:                       0.3       0.50      19.9
# 8. Students % Asian:                                 0.4       1.00      55.4
# 9. Students % Pacific Islander:                      0.0       0.10      17.7
# 10. Students % Two or More Races:                    2.2       3.40      13.4
# 11. Students % Economically Disadvantaged:          61.8      74.55     100.0
# 12. Students % English Learners (EL):                6.6      14.65      73.9
# 13. Students % Special Education:                   10.1      11.70      34.4
# 14. Students % Bilingual/ESL Education:              6.4      14.50      73.9
# 15. Students % Career and Technical Education:      29.7      34.00      99.3
# 16. Students % Gifted and Talented Education:        5.6       7.70      24.1
# 17. Attendance Rate (2017-18):                      95.7      96.20     100.0
# 18. Annual Dropout Rate Gr. 9-12 (2017-18):          0.4       1.10      37.0
# 22. Annual Graduate Count (2017-18):                71.0     223.00   11005.0

# %%
students = pd.melt(readablesnapshot[['DISTRICT #', 'total students']], 
                        id_vars='DISTRICT #', 
                        #var_name='Ticket', 
                        #value_vars=['AdultWeekday', 'AdultWeekend'], 
                        value_name='students')

# %%
#ax = df.plot.hist(bins=12, alpha=0.5)
histogram = readablesnapshot['total students'].plot.hist(bins=10)

# %%
#Ok I can see that there seem so be a small number of schools with a much larger number of students.
#Let's see which schools they are
readablesnapshot[readablesnapshot['total students'] > 100000]
# Out:
#                   DISTNAME  DISTRICT #    DZCNTYNM  REGION DZRATING  DZCAMPUS  \
# 85           NORTHSIDE ISD       15915   015 BEXAR      20        B       120
# 280             DALLAS ISD       57905  057 DALLAS      10        B       232
# 521  CYPRESS-FAIRBANKS ISD      101907  101 HARRIS       4        B        87
# 525            HOUSTON ISD      101912  101 HARRIS       4        B       279
#
#      total students  4. Students % African American:   \
# 85           105797                               6.6
# 280          155030                              22.0
# 521          116245                              18.6
# 525          209040                              23.3
#
#      5. Students % Hispanic:   6. Students % White:  ...  \
# 85                       68.0                  18.8  ...
# 280                      69.6                   5.6  ...
# 521                      44.4                  24.1  ...
# 525                      62.0                   9.0  ...
#
#      96. Expenditures % Career and Technical Education:  \
# 85                                                 2.3
# 280                                                2.2
# 521                                                2.6
# 525                                                1.9
#
#      97. Expenditures % Gifted and Talented Education:  \
# 85                                                 1.0
# 280                                                0.5
# 521                                                0.5
# 525                                                0.4
#
#      98. Expenditures % Athletics/Related Activities:  \
# 85                                                1.7
# 280                                               1.2
# 521                                               1.3
# 525                                               0.6
#
#      99. Expenditures % High School Allotment:  \
# 85                                         0.9
# 280                                        1.1
# 521                                        2.4
# 525                                        1.3
#
#      100. Expenditures % Prekindergarten:  101. Expenditures % Un-Allocated:  \
# 85                                    0.7                               20.9
# 280                                   0.6                               23.9
# 521                                   0.8                               25.5
# 525                                   1.1                               27.3
#
#             DISTSIZE        COMMTYPE                PROPWLTH  \
# 85   50,000 and over     Major Urban  $442,675 to < $456,961
# 280  50,000 and over     Major Urban  $639,298 to < $741,925
# 521  50,000 and over  Major Suburban  $413,609 to < $442,675
# 525  50,000 and over     Major Urban  $741,925 to < $786,525
#
#                       TAXRATE
# 85   $1.3050 to under $1.4272
# 280  $1.1701 to under $1.3050
# 521          $1.4272 and over
# 525  $1.1701 to under $1.3050
#
# [4 rows x 113 columns]

# %%
readablesnapshot['total students'].min()
# Out:
# 38

# %%
readablesnapshot[readablesnapshot['total students'] < 100]
# Out:
#                 DISTNAME  DISTRICT #        DZCNTYNM  REGION DZRATING  \
# 126         MARATHON ISD       22902    022 BREWSTER      18        A
# 321   PATTON SPRINGS ISD       63906     063 DICKENS      17        B
# 622        DELL CITY ISD      115903    115 HUDSPETH      19        D
# 650        VALENTINE ISD      122902  122 JEFF DAVIS      18        A
# 784             LOHN ISD      160905   160 MCCULLOCH      15        B
# 1147          KELTON ISD      242905     242 WHEELER      16        A
#
#       DZCAMPUS  total students  4. Students % African American:   \
# 126          1              55                               0.0
# 321          1              97                               3.1
# 622          1              72                               0.0
# 650          1              38                               0.0
# 784          1              75                               0.0
# 1147         1              90                               1.1
#
#       5. Students % Hispanic:   6. Students % White:  ...  \
# 126                       60.0                  38.2  ...
# 321                       44.3                  52.6  ...
# 622                       62.5                  37.5  ...
# 650                       71.1                  21.1  ...
# 784                       41.3                  56.0  ...
# 1147                      37.8                  55.6  ...
#
#       96. Expenditures % Career and Technical Education:  \
# 126                                                 3.2
# 321                                                 2.9
# 622                                                 0.3
# 650                                                 1.9
# 784                                                 6.7
# 1147                                                4.0
#
#       97. Expenditures % Gifted and Talented Education:  \
# 126                                                 0.0
# 321                                                 0.2
# 622                                                 0.0
# 650                                                 0.0
# 784                                                 0.2
# 1147                                                0.0
#
#       98. Expenditures % Athletics/Related Activities:  \
# 126                                                2.1
# 321                                                4.0
# 622                                                3.2
# 650                                                4.8
# 784                                                3.0
# 1147                                               0.5
#
#       99. Expenditures % High School Allotment:  \
# 126                                         3.8
# 321                                         0.4
# 622                                         0.0
# 650                                         0.2
# 784                                         0.4
# 1147                                        1.0
#
#       100. Expenditures % Prekindergarten:  101. Expenditures % Un-Allocated:  \
# 126                                    4.2                               38.7
# 321                                    1.2                               49.0
# 622                                    0.0                               46.3
# 650                                    4.9                               32.0
# 784                                    0.7                               35.8
# 1147                                   6.2                               42.8
#
#        DISTSIZE  COMMTYPE                PROPWLTH                   TAXRATE
# 126   Under 500     Rural       $786,525 and over             Under $1.1701
# 321   Under 500     Rural       $786,525 and over             Under $1.1701
# 622   Under 500     Rural       $786,525 and over             Under $1.1701
# 650   Under 500     Rural       $786,525 and over             Under $1.1701
# 784   Under 500     Rural  $250,173 to < $272,534  $1.1701 to under $1.3050
# 1147  Under 500     Rural       $786,525 and over             Under $1.1701
#
# [6 rows x 113 columns]

# %%
#This explains why the standard deviation is so high in certain categories that would relate to student populations. 
#Let's look at some other numeric features to see if there are any outliers
readablesnapshot.iloc[:,4:20].hist(figsize=(15,10))
plt.subplots_adjust(hspace=.5);

# %%
readablesnapshot.iloc[:,20:40].hist(figsize=(15,10))
plt.subplots_adjust(hspace=.5);

# %%
readablesnapshot.iloc[:,40:60].hist(figsize=(15,10))
plt.subplots_adjust(hspace=.5);

# %%
#ACT average score stands out as odd
readablesnapshot.iloc[:,60:80].hist(figsize=(15,10))
plt.subplots_adjust(hspace=.5);

# %%
#Number of students per total staff may need some closer examination. Something is driving the graph into the 600's. 
readablesnapshot.iloc[:,80:-5].hist(figsize=(15,10))
plt.subplots_adjust(hspace=.5);

# %% [markdown]
# To do:
# -take a closer look at ACT average score and total number of students per staff to see where the outliers are
# -create a racial difference column by:
# 1- taking the difference between each %race teacher and %race students per district to make difference per race columns
# 2- if the number is negative x = x+2x
# 3- take the average of each race and use it to create average racial difference column to see how it affects grad rates

# %%
readablesnapshot[readablesnapshot['55. Number of Students Per Total Staff: ']>100 ]
# Out:
#                             DISTNAME  DISTRICT #    DZCNTYNM  REGION DZRATING  \
# 268  RICHLAND COLLEGIATE HIGH SCHOOL       57840  057 DALLAS      10        A
#
#      DZCAMPUS  total students  4. Students % African American:   \
# 268         1             592                              24.7
#
#      5. Students % Hispanic:   6. Students % White:  ...  \
# 268                      29.6                  17.7  ...
#
#      96. Expenditures % Career and Technical Education:  \
# 268                                               12.1
#
#      97. Expenditures % Gifted and Talented Education:  \
# 268                                                0.0
#
#      98. Expenditures % Athletics/Related Activities:  \
# 268                                               0.0
#
#      99. Expenditures % High School Allotment:  \
# 268                                        3.8
#
#      100. Expenditures % Prekindergarten:  101. Expenditures % Un-Allocated:  \
# 268                                   0.0                                8.7
#
#        DISTSIZE  COMMTYPE             PROPWLTH              TAXRATE
# 268  500 to 999  Charters  Non-taxing entities  Non-taxing entities
#
# [1 rows x 113 columns]

# %%
readablesnapshot.loc[readablesnapshot['55. Number of Students Per Total Staff: '] > 100, ['DISTNAME','55. Number of Students Per Total Staff: ']]
#df.loc[df['a'] > 10, ['a','c']]
# Out:
#                             DISTNAME  55. Number of Students Per Total Staff:
# 268  RICHLAND COLLEGIATE HIGH SCHOOL                                     615.0

# %%
description.head()
# Out:
#                                    count           mean           std     min  \
# DISTRICT #                        1067.0  123953.454545  73363.631071  1902.0
# REGION                            1067.0      10.556701      5.293569     1.0
# DZCAMPUS                          1067.0       8.089972     17.592728     1.0
# total students                    1067.0    5023.809747  13631.436300    38.0
# 4. Students % African American:   1067.0       7.518650     11.418823     0.0
#
#                                       25%       50%        75%       max
# DISTRICT #                        61852.5  113906.0  184903.50  254902.0
# REGION                                7.0      11.0      15.00      20.0
# DZCAMPUS                              2.0       3.0       6.00     279.0
# total students                      450.0    1079.0    3265.00  209040.0
# 4. Students % African American:       0.7       2.7      10.25      94.9

# %%
descriptionindex = description.reset_index()
descriptionindex.head()
# Out:
#                               index   count           mean           std  \
# 0                        DISTRICT #  1067.0  123953.454545  73363.631071
# 1                            REGION  1067.0      10.556701      5.293569
# 2                          DZCAMPUS  1067.0       8.089972     17.592728
# 3                    total students  1067.0    5023.809747  13631.436300
# 4  4. Students % African American:   1067.0       7.518650     11.418823
#
#       min      25%       50%        75%       max
# 0  1902.0  61852.5  113906.0  184903.50  254902.0
# 1     1.0      7.0      11.0      15.00      20.0
# 2     1.0      2.0       3.0       6.00     279.0
# 3    38.0    450.0    1079.0    3265.00  209040.0
# 4     0.0      0.7       2.7      10.25      94.9

# %%
descriptionindex.loc[descriptionindex['index'] == '55. Number of Students Per Total Staff: ']
#Is seems I also have a district where the min is 0. Let's see what's up
# Out:
#                                        index   count      mean        std  \
# 59  55. Number of Students Per Total Staff:   1067.0  7.316041  18.677741
#
#     min  25%  50%  75%    max
# 59  0.0  5.8  6.7  7.6  615.0

# %%
readablesnapshot.loc[readablesnapshot['55. Number of Students Per Total Staff: '] < 1, ['DISTNAME','55. Number of Students Per Total Staff: ']]
# Out:
#                                DISTNAME  \
# 194  IMAGINE INTERNATIONAL ACADEMY OF N
#
#      55. Number of Students Per Total Staff:
# 194                                       0.0

# %%
#These outliers must be in error. I'll remove both districts just to be sure
rid_imagine = readablesnapshot['DISTNAME'] == 'IMAGINE INTERNATIONAL ACADEMY OF N'

# %%
readablesnapshot = readablesnapshot[~rid_imagine]

# %%
rid_richland = readablesnapshot['DISTNAME'] == 'RICHLAND COLLEGIATE HIGH SCHOOL'
readablesnapshot = readablesnapshot[~rid_richland]

# %%
readablesnapshot.loc[:, '55. Number of Students Per Total Staff: '].hist(figsize=(15,10))
plt.subplots_adjust(hspace=.5)
#That's MUCH better!

# %%
readablesnapshot[readablesnapshot['43. Total Teacher FTE: ']>10000 ]
#The total teachers FTE column seemed odd, but it makes sense for the two largest districts in the state to have so many teachers
#This should also be the case for any statistic that would involve the number of students
# Out:
#         DISTNAME  DISTRICT #    DZCNTYNM  REGION DZRATING  DZCAMPUS  \
# 280   DALLAS ISD       57905  057 DALLAS      10        B       232
# 525  HOUSTON ISD      101912  101 HARRIS       4        B       279
#
#      total students  4. Students % African American:   \
# 280          155030                              22.0
# 525          209040                              23.3
#
#      5. Students % Hispanic:   6. Students % White:  ...  \
# 280                      69.6                   5.6  ...
# 525                      62.0                   9.0  ...
#
#      96. Expenditures % Career and Technical Education:  \
# 280                                                2.2
# 525                                                1.9
#
#      97. Expenditures % Gifted and Talented Education:  \
# 280                                                0.5
# 525                                                0.4
#
#      98. Expenditures % Athletics/Related Activities:  \
# 280                                               1.2
# 525                                               0.6
#
#      99. Expenditures % High School Allotment:  \
# 280                                        1.1
# 525                                        1.3
#
#      100. Expenditures % Prekindergarten:  101. Expenditures % Un-Allocated:  \
# 280                                   0.6                               23.9
# 525                                   1.1                               27.3
#
#             DISTSIZE     COMMTYPE                PROPWLTH  \
# 280  50,000 and over  Major Urban  $639,298 to < $741,925
# 525  50,000 and over  Major Urban  $741,925 to < $786,525
#
#                       TAXRATE
# 280  $1.1701 to under $1.3050
# 525  $1.1701 to under $1.3050
#
# [2 rows x 113 columns]

# %%
#Double checking on the largest schools
readablesnapshot.loc[readablesnapshot['23. Annual RHSP/DAP/FHSP-E/FHSP-DLA Graduate Count (2017-18):'] > 5000, ['DISTNAME','23. Annual RHSP/DAP/FHSP-E/FHSP-DLA Graduate Count (2017-18):']]
# Out:
#                   DISTNAME  \
# 85           NORTHSIDE ISD
# 280             DALLAS ISD
# 399          FORT BEND ISD
# 521  CYPRESS-FAIRBANKS ISD
# 525            HOUSTON ISD
#
#      23. Annual RHSP/DAP/FHSP-E/FHSP-DLA Graduate Count (2017-18):
# 85                                              6074.0
# 280                                             6687.0
# 399                                             5186.0
# 521                                             6443.0
# 525                                             9788.0

# %%
#Now let's make sure there are no low outliers
readablesnapshot.loc[readablesnapshot['23. Annual RHSP/DAP/FHSP-E/FHSP-DLA Graduate Count (2017-18):'] < 1, ['DISTNAME','23. Annual RHSP/DAP/FHSP-E/FHSP-DLA Graduate Count (2017-18):']]
# Out:
#               DISTNAME  \
# 133            MAY ISD
# 562       LAPOYNOR ISD
# 1081  THE EXCEL CENTER
#
#       23. Annual RHSP/DAP/FHSP-E/FHSP-DLA Graduate Count (2017-18):
# 133                                                 0.0
# 562                                                 0.0
# 1081                                                0.0

# %%
#There are three schools with NO graduates. Taking a closer look at one of them
may_isd = readablesnapshot[readablesnapshot['DISTNAME'] == 'MAY ISD']
may_isd.iloc[:,0:10]
# Out:
#     DISTNAME  DISTRICT #   DZCNTYNM  REGION DZRATING  DZCAMPUS  \
# 133  MAY ISD       25905  025 BROWN      15        B         2
#
#      total students  4. Students % African American:   \
# 133             266                               1.9
#
#      5. Students % Hispanic:   6. Students % White:
# 133                      20.7                  74.8

# %%
may_isd.iloc[:,10:20]
# Out:
#      7. Students % American Indian:  8. Students % Asian:  \
# 133                             0.0                   0.0
#
#      9. Students % Pacific Islander:  10. Students % Two or More Races:  \
# 133                              0.4                                2.3
#
#      11. Students % Economically Disadvantaged:  \
# 133                                        69.5
#
#      12. Students % English Learners (EL):  13. Students % Special Education:  \
# 133                                    2.3                                9.4
#
#      14. Students % Bilingual/ESL Education:  \
# 133                                      2.3
#
#      15. Students % Career and Technical Education:  \
# 133                                            35.0
#
#      16. Students % Gifted and Talented Education:
# 133                                            6.8

# %%
may_isd.iloc[:,20:30]
# Out:
#      17. Attendance Rate (2017-18):  \
# 133                            96.0
#
#      18. Annual Dropout Rate Gr. 9-12 (2017-18):  \
# 133                                          0.0
#
#      22. Annual Graduate Count (2017-18):  \
# 133                                  26.0
#
#      23. Annual RHSP/DAP/FHSP-E/FHSP-DLA Graduate Count (2017-18):  \
# 133                                                0.0
#
#      staar all subjects approach  staar all subjects meet  \
# 133                         76.0                     45.0
#
#      staar all subjects master  staar elar approach  staar elar meets  \
# 133                       16.0                 75.0              49.0
#
#      staar elar master
# 133               21.0

# %%
#Wait no. These schools must just not participate in the RHSP ect program. Let's examine straight graduate count instead
readablesnapshot.loc[readablesnapshot['22. Annual Graduate Count (2017-18):'] < 1, ['DISTNAME','22. Annual Graduate Count (2017-18):']]
# Out:
# Empty DataFrame
# Columns: [DISTNAME, 22. Annual Graduate Count (2017-18):]
# Index: []

# %%
#This looks good. Now to check out the odd ACT score
testtype = readablesnapshot.loc[readablesnapshot['41. ACT - Average Score (2017-2018):'] < 1, ['DISTNAME','41. ACT - Average Score (2017-2018):']]
type(testtype.iloc[1,1])
# Out:
# numpy.float64

# %%
#Lot's of negative results. Taking a look at the snapshot report for ELKHART ISD the document
#Indicates that these numbers were masked to protect student confidentiality. Too few students took the ACT at these districts
readable2 = readablesnapshot.replace(float('-1'),np.NaN, inplace=False)

# %%
missing = pd.concat([readable2.isnull().sum(), 100 * readable2.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by='count')
missing[missing['%']>0 ]
# Out:
#                                                     count          %
# staar math approach                                     1   0.093897
# staar math meet                                         1   0.093897
# staar math master                                       1   0.093897
# staar science approach                                  1   0.093897
# staar science meet                                      1   0.093897
# staar science master                                    1   0.093897
# staar social approach                                   3   0.281690
# staar social meet                                       3   0.281690
# staar social master                                     3   0.281690
# 38. SAT/ACT Results - % Tested (2017-2018):             7   0.657277
# 39. SAT/ACT Results - % At or Above Criterion (...     48   4.507042
# 40. SAT - Average Score (2017-2018):                  197  18.497653
# 41. ACT - Average Score (2017-2018):                   93   8.732394

# %%
missingcols = ['staar math approach',
'staar math meet',
'staar math master',
'staar science approach',
'staar science meet',
'staar science master',
'staar social approach',
'staar social meet',
'staar social master',
'38. SAT/ACT Results - % Tested (2017-2018):',
'39. SAT/ACT Results - % At or Above Criterion (2017-2018): ',]

# %%
readable2.drop(columns=['40. SAT - Average Score (2017-2018):',
'41. ACT - Average Score (2017-2018):'], inplace= True)

# %%
missingcolmeans2 = []
for miss in missingcols:
    missingcolmeans2.append(readable2[miss].mean())

# %%
replacewithmeans2 = dict(zip(missingcols, missingcolmeans2))

# %%
for i in missingcols:
    readable2[i].fillna(replacewithmeans2[i], inplace=True)

# %%
missing = pd.concat([readable2.isnull().sum(), 100 * readable2.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by='count')
missing[missing['%']>0 ]
# Out:
# Empty DataFrame
# Columns: [count, %]
# Index: []

# %%
#Now there are no missing values in the whole dataset. 
#Let's drop the categorical data that I couldn't fix.
readable2.iloc[:5,-2:]
# Out:
#                  PROPWLTH                   TAXRATE
# 0  $442,675 to < $456,961             Under $1.1701
# 1  $164,221 to < $208,918  $1.3050 to under $1.4272
# 2  $272,534 to < $299,260          $1.4272 and over
# 3  $272,534 to < $299,260          $1.4272 and over
# 4  $299,260 to < $316,695          $1.4272 and over

# %%
readable2.drop(columns=['PROPWLTH',
'TAXRATE'], inplace= True)

# %%
#I want to make one extra column to measure racial differences between teachers and students to see if it makes an impact

# %%
readable2['afrdiff'] = 0
readable2['hispdiff'] = 0
readable2['whidiff'] = 0
readable2['asndiff'] = 0
readable2['pacdiff'] = 0

# %%
# Out:
# DISTNAME
# DISTRICT #
# DZCNTYNM
# REGION
# DZRATING
# DZCAMPUS
# total students
# 4. Students % African American:
# 5. Students % Hispanic:
# 6. Students % White:
# 7. Students % American Indian:
# 8. Students % Asian:
# 9. Students % Pacific Islander:
# 10. Students % Two or More Races:
# 11. Students % Economically Disadvantaged:
# 12. Students % English Learners (EL):
# 13. Students % Special Education:
# 14. Students % Bilingual/ESL Education:
# 15. Students % Career and Technical Education:
# 16. Students % Gifted and Talented Education:
# 17. Attendance Rate (2017-18):
# 18. Annual Dropout Rate Gr. 9-12 (2017-18):
# 22. Annual Graduate Count (2017-18):
# 23. Annual RHSP/DAP/FHSP-E/FHSP-DLA Graduate Count (2017-18):
# staar all subjects approach
# staar all subjects meet
# staar all subjects master
# staar elar approach
# staar elar meets
# staar elar master
# staar write approach
# staar write meet
# staar write master
# staar math approach
# staar math meet
# staar math master
# staar science approach
# staar science meet
# staar science master
# staar social approach
# staar social meet
# staar social master
# econ disad approach
# econ disad meet
# econ disad master
# 38. SAT/ACT Results - % Tested (2017-2018):
# 39. SAT/ACT Results - % At or Above Criterion (2017-2018):
# 42. Total Staff FTE:
# 43. Total Teacher FTE:
# 44. Staff % Central Administration:
# 45. Staff % Campus Administration:
# 46. Staff % Professional Support:
# 47. Staff % Teachers:
# 48. Staff % Educational Aides:
# 49. Staff % Auxiliary:
# 50. Average Central Administrative Salary:
# 51. Average Campus Administrative Salary:
# 52. Average Professional Support Staff Salary:
# 53. Average Teacher Salary:
# 54. Staff % Minority:
# 55. Number of Students Per Total Staff:
# 56. Number of Students Per Teacher:
# 57. Teacher % With 5 or Fewer Years of Experience:
# 58. Teacher Average Years of Experience:
# 59. Teacher % With Advanced Degrees:
# 60. Teacher Turnover Rate:
# 61. Teacher % African American:
# 62. Teacher % Hispanic:
# 63. Teacher % White:
# 64. Teacher % Other:
# 65. Teacher % Regular Education:
# 66. Teacher % Special Education:
# 67. Teacher % Compensatory Education:
# 68. Teacher % Bilingual/ESL Education:
# 69. Teacher % Career and Technical Education:
# 70. Teacher % Other Education (Includes Gifted and Talented):
# 71. Taxable Value Per Pupil (2016 Tax Year):
# 72. Locally Adopted Tax Rate (2017 Tax Year):
# 73. Total Operating and Other Revenue (2017-18):
# 74. Total Operating and Other Revenue Per Pupil:
# 75. Total Operating Revenue (2017-18):
# 76. Operating Revenue % State:
# 77. Operating Revenue % Local and Other:
# 78. Operating Revenue % Federal:
# 79. Total Other Revenue (2017-18):
# 80. Fund Balance (For ISDs):
# 81. Net Assets (Charter Schools):
# 82. Total Actual Expenditures (2017-18):
# 83. Total Actual Operating Expenditures (2017-18):
# 84. Total Actual Operating Expenditures Per Pupil:
# 85. Expenditure % Instructional:
# 86. Expenditure % Central Administrative:
# 87. Expenditure % School Leadership:
# 88. Expenditure % Plant Services:
# 89. Expenditure % Other Operating:
# 90. Total Actual Instructional Expenditures (2017-2018):
# 91. Total Actual Instructional Expenditures Per Pupil:
# 92. Expenditures % Basic Education Services:
# 93. Expenditures % Special Education:
# 94. Expenditures % State Compensatory Education:
# 95. Expenditures % Bilingual/ESL Education:
# 96. Expenditures % Career and Technical Education:
# 97. Expenditures % Gifted and Talented Education:
# 98. Expenditures % Athletics/Related Activities:
# 99. Expenditures % High School Allotment:
# 100. Expenditures % Prekindergarten:
# 101. Expenditures % Un-Allocated:
# DISTSIZE
# COMMTYPE
# afrdiff
# hispdiff
# whidiff
# asndiff
# pacdiff

# %%
#for row in readable2.iterrows():
    #print(row)
    #affdif = row['4. Students % African American: '] - row['61. Teacher % African American:']
    #if affdif > 0:
        #row['affdif'] = affdif

# %%
affdif = readable2['4. Students % African American: '] - readable2['61. Teacher % African American:']

# %%
readable2['affdif'] = affdif

# %%
readable2['affdif'] = readable2['affdif'] .abs()

# %%
hispdif = readable2['5. Students % Hispanic: '] - readable2['62. Teacher % Hispanic:']
whidif = readable2['6. Students % White:'] - readable2['63. Teacher % White:']
othdif = ((readable2['7. Students % American Indian:'] + readable2['7. Students % American Indian:'] + 
readable2['8. Students % Asian:'] + readable2['9. Students % Pacific Islander:']) / 4) - readable2['64. Teacher % Other:']

# %%
hispdif = hispdif.abs()
whidif = whidif.abs()
othdif = othdif.abs()

# %%
readable2['hispdif'] = hispdif
readable2['whidif'] = whidif
readable2['othdif'] = othdif

# %%
readable2['Racial Dif Stu/Tea'] = (readable2['affdif'] + readable2['hispdif'] + readable2['whidif'] + readable2['othdif']) / 4

# %%
readable2.drop(columns=['affdif',
'hispdif', 'whidif', 'othdif'], inplace= True)

# %%
#I now have a column that summarizes the average difference in racial makeup between students and teachers

# %% [markdown]
# To summarize what I've done to this dataframe:
#
# -renamed the columns for readability
# -removed columns with a high % of missing data
# -Imputed the mean for columns with a low amount of missing data
# -Graphed the data to look for erroneous entries and removed those rows
# -Dropped categorical data that was not useful
# -Created a new column to measure racial differences between students and staff (I'm just curious to see if this will impact
# graduation rates)

# %%
readable2.to_csv('wrangled_snapshot.csv')
